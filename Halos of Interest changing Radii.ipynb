# %%
import numpy as np
import pynbody
import matplotlib.pyplot as plt
import matplotlib as mpl
import pynbody.plot as pp
import pickle
import pandas as pd
import pynbody.plot.sph as sph

# %%
from Time import *
from Load import *
from Load import *

# %% [markdown]
# # H148

# %%
i = 2
print("Halo 2")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 2

# %%
i = 3
print("Halo 3")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 3

# %%
i = 5
print("Halo 5")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 5

# %%
i = 6
print("Halo 6")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 6

# %%
i = 9
print("Halo 9")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 9

# %%
i = 11
print("Halo 11")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 11

# %%
i = 13
print("Halo 13")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 13

# %%
i = 14
print("Halo 14")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 14

# %%
i = 21
print("Halo 21")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 21

# %%
i = 27
print("Halo 27")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 27

# %%
i = 28
print("Halo 28")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 28

# %%
i = 32
print("Halo 32")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 32

# %%
i = 36
print("Halo 36")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 36

# %%
i = 37
print("Halo 37")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 37

# %%
i = 45
print("Halo 45")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 45

# %%
i = 68
print("Halo 68")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 68

# %%
i = 80
print("Halo 80")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 80

# %%
i = 163
print("Halo 163")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 163

# %%
i = 278
print("Halo 278")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 278

# %%
i = 283
print("Halo 283")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 283

# %%
i = 329
print("Halo 329")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat1['time'][datat1['z0haloid']==i], datat1['h1dist'][datat1['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat1['time'][datat1['z0haloid']==i], datat1['Rvir'][datat1['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo

# %%
i = 20
print("Halo 20")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat2['time'][datat2['z0haloid']==i], datat2['h1dist'][datat2['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat2['time'][datat2['z0haloid']==i], datat2['Rvir'][datat2['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 20

# %%
i = 22
print("Halo 22")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat2['time'][datat2['z0haloid']==i], datat2['h1dist'][datat2['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat2['time'][datat2['z0haloid']==i], datat2['Rvir'][datat2['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 22

# %%
i = 23
print("Halo 23")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat2['time'][datat2['z0haloid']==i], datat2['h1dist'][datat2['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat2['time'][datat2['z0haloid']==i], datat2['Rvir'][datat2['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 23

# %%
i = 27
print("Halo 27")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat2['time'][datat2['z0haloid']==i], datat2['h1dist'][datat2['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat2['time'][datat2['z0haloid']==i], datat2['Rvir'][datat2['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 27

# %%
i = 52
print("Halo 52")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat2['time'][datat2['z0haloid']==i], datat2['h1dist'][datat2['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat2['time'][datat2['z0haloid']==i], datat2['Rvir'][datat2['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 52

# %%
i = 53
print("Halo 53")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat2['time'][datat2['z0haloid']==i], datat2['h1dist'][datat2['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat2['time'][datat2['z0haloid']==i], datat2['Rvir'][datat2['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 53

# %%
i = 55
print("Halo 55")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat2['time'][datat2['z0haloid']==i], datat2['h1dist'][datat2['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat2['time'][datat2['z0haloid']==i], datat2['Rvir'][datat2['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 55

# %%
i = 10
print("Halo 10")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat3['time'][datat3['z0haloid']==i], datat3['h1dist'][datat3['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat3['time'][datat3['z0haloid']==i], datat3['Rvir'][datat3['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 10

# %%
i = 12
print("Halo 12")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat3['time'][datat3['z0haloid']==i], datat3['h1dist'][datat3['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat3['time'][datat3['z0haloid']==i], datat3['Rvir'][datat3['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 12

# %%
i = 24
print("Halo 24")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat3['time'][datat3['z0haloid']==i], datat3['h1dist'][datat3['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat3['time'][datat3['z0haloid']==i], datat3['Rvir'][datat3['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 24

# %%
i = 30
print("Halo 30")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat3['time'][datat3['z0haloid']==i], datat3['h1dist'][datat3['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat3['time'][datat3['z0haloid']==i], datat3['Rvir'][datat3['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 30

# %%
i = 41
print("Halo 41")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat3['time'][datat3['z0haloid']==i], datat3['h1dist'][datat3['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat3['time'][datat3['z0haloid']==i], datat3['Rvir'][datat3['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 41

# %%
i = 80
print("Halo 80")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat3['time'][datat3['z0haloid']==i], datat3['h1dist'][datat3['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat3['time'][datat3['z0haloid']==i], datat3['Rvir'][datat3['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 80

# %%
i = 223
print("Halo 223")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat3['time'][datat3['z0haloid']==i], datat3['h1dist'][datat3['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat3['time'][datat3['z0haloid']==i], datat3['Rvir'][datat3['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 223

# %%
i = 439
print("Halo 439")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat3['time'][datat3['z0haloid']==i], datat3['h1dist'][datat3['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat3['time'][datat3['z0haloid']==i], datat3['Rvir'][datat3['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 439

# %%
i = 11
print("Halo 11")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat4['time'][datat4['z0haloid']==i], datat4['h1dist'][datat4['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat4['time'][datat4['z0haloid']==i], datat4['Rvir'][datat4['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 11

# %%
i = 31
print("Halo 31")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat4['time'][datat4['z0haloid']==i], datat4['h1dist'][datat4['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat4['time'][datat4['z0haloid']==i], datat4['Rvir'][datat4['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 31

# %%
i = 33
print("Halo 33")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat4['time'][datat4['z0haloid']==i], datat4['h1dist'][datat4['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat4['time'][datat4['z0haloid']==i], datat4['Rvir'][datat4['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 33

# %%
i = 133
print("Halo 133")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat4['time'][datat4['z0haloid']==i], datat4['h1dist'][datat4['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat4['time'][datat4['z0haloid']==i], datat4['Rvir'][datat4['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 133

# %%
i = 137
print("Halo 137")

plt.figure(figsize=(7,5))
fig, ax1 = plt.subplots()
ax1.set_xlabel('Gyr')
ax1.set_ylabel('Distance', color='black')
ax1.plot(datat4['time'][datat4['z0haloid']==i], datat4['h1dist'][datat4['z0haloid']==i], c='black')
ax1.semilogy()
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Rvir', color='m')  # we already handled the x-label with ax1
ax2.plot(datat4['time'][datat4['z0haloid']==i], datat4['Rvir'][datat4['z0haloid']==i], c='m', label='Rvir')
ax2.semilogy()
ax2.tick_params(axis='y', labelcolor='m')
plt.legend()
plt.show()
# Out:
# Halo 137
