# %%
import numpy as np
import pynbody
import matplotlib.pyplot as plt
import matplotlib as mpl
import pynbody.plot as pp
import pickle
import pandas as pd
import pynbody.plot.sph as sph

# %%
from Star import *

# %%
#Vc == ((Gravitational constant * Halo Mass)/Rvir)**(1/2)
G = 4.302*1e-3           #in pc/Msol(km/s)**2
h = 0.6776942783267969          #halo.properties['h']
Rvir = data['Rvir']*1000*h
V_c = (G* data['mass']/Rvir)**(1/2)     #km/s

# %%
s1 = pynbody.load(sim1)
h1 = s1.halos()
s1.physical_units()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-59cab286d200> in <module>
# ----> 1 s1 = pynbody.load(sim1)
#       2 h1 = s1.halos()
#       3 s1.physical_units()
#
# ~/anaconda3/lib/python3.7/site-packages/pynbody/snapshot/__init__.py in load(filename, *args, **kwargs)
#    1985
#    1986     raise IOError(
# -> 1987         "File %r: format not understood or does not exist" % filename)
#    1988
#    1989 def new(n_particles=0, order=None, **families):
#
# OSError: File '/home/akinshol/Data/DataFiles/h148': format not understood or does not exist

# %%
s2 = pynbody.load(sim2)
h2 = s2.halos()
s2.physical_units()

# %%
s3 = pynbody.load(sim3)
h3 = s3.halos()
s3.physical_units()

# %%
s4 = pynbody.load(sim4)
h4 = s4.halos()
s4.physical_units()

# %%
#Plot N value vs Stellar Mass
# EQ

n = 3.6*(data['M_star']/10**10)**(-.35)     #unitlessRogue['G_outflow_1.5']

#   *1.989e30

plt.figure(figsize=(7,7))
#plt.scatter(data['mass'], n, c='b')

plt.scatter(data['M_star'], data['G_outflow_2.5']/data['SFR'], c='r')
plt.plot(data['M_star'], n, c='grey')

plt.loglog()
plt.ylim(5e-2, 5e2)
plt.xlim(1e3, 1e12)

plt.xlabel(r'Stellar Mass ($M_{\odot}$) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Power Law Fit Muratov 2.5', size=20)
plt.savefig('a')

# %%
plt.figure(figsize=(7,7))
#plt.scatter(data['mass'], n, c='b')

plt.scatter(data['M_star'], data['G_outflow_0']/data['SFR'], c='r')
plt.plot(data['M_star'], n, c='grey')

plt.loglog()
plt.ylim(5e-3, 5e2)
plt.xlim(1e3, 1e12)

plt.xlabel(r'Stellar Mass ($M_{\odot}$) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Power Law Fit Muratov 0', size=20)
plt.savefig('a1')

# %%
plt.figure(figsize=(7,7))
#plt.scatter(data['mass'], n, c='b')

plt.scatter(data['M_star'], data['G_outflow_0']/data['SFR'], c='r')
plt.scatter(data['M_star'][data['sSFR']<1e-11], data['G_outflow_0'][data['sSFR']<1e-11]/data['SFR'][data['sSFR']<1e-11], c='b')
plt.plot(data['M_star'], n, c='grey')

plt.loglog()
plt.ylim(5e-3, 5e2)
plt.xlim(1e3, 1e12)

plt.xlabel(r'Stellar Mass ($M_{\odot}$) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Power Law Fit Muratov 0', size=20)
plt.savefig('a1')

plt.figure(figsize=(7,7))
#plt.scatter(data['mass'], n, c='b')

plt.scatter(data['M_star'], data['G_outflow_0']/data['SFR'], c='r')
plt.scatter(data['M_star'][data['sSFR']>1e-11], data['G_outflow_0'][data['sSFR']>1e-11]/data['SFR'][data['sSFR']>1e-11], c='b')
plt.plot(data['M_star'], n, c='grey')

plt.loglog()
plt.ylim(5e-3, 5e2)
plt.xlim(1e3, 1e12)

plt.xlabel(r'Stellar Mass ($M_{\odot}$) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Power Law Fit Muratov 0', size=20)
plt.savefig('a1')

# %%
#Plot N value vs Stellar Mass
# EQ

n = 3.6*(data['M_star']/10**10)**(-.35)     #unitlessRogue['G_outflow_1.5']

#   *1.989e30

plt.figure(figsize=(7,7))
#plt.scatter(data['mass'], n, c='b')

plt.scatter(data['M_star'], data['G_outflow_1.5']/data['SFR'], c='r')
plt.plot(data['M_star'], n, c='grey')

plt.loglog()
plt.ylim(5e-2, 5e2)
plt.xlim(1e3, 1e12)

plt.xlabel(r'Stellar Mass ($M_{\odot}$) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Power Law Fit Muratov 1.5', size=20)
plt.savefig('a1')

# %%
#Plot N value vs Stellar Mass
# EQ

n = 3.6*(data['M_star']/10**10)**(-.35)     #unitlessRogue['G_outflow_1.5']

#   *1.989e30

plt.figure(figsize=(7,7))
#plt.scatter(data['mass'], n, c='b')

plt.scatter(data['M_star'], data['G_outflow_0']/data['SFR'], c='black', s=30, label='0')
plt.scatter(data['M_star'], data['G_outflow_1.5']/data['SFR'], c='maroon', s=30, label='1.5')
plt.scatter(data['M_star'], data['G_outflow_2.5']/data['SFR'], c='tomato', s=30, label='2.5')
plt.legend()
plt.plot(data['M_star'], n, c='grey')

plt.loglog()
plt.ylim(5e-3, 5e2)
plt.xlim(1e3, 1e12)

plt.xlabel(r'Stellar Mass ($M_{\odot}$) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Power Law Fit Muratov', size=20)
plt.savefig('a2')

# %%
#Plot N value vs Stellar Mass
# EQ

n = 3.6*(data['M_star']/10**10)**(-.35)     #unitlessRogue['G_outflow_1.5']

#   *1.989e30

plt.figure(figsize=(7,7))
#plt.scatter(data['mass'], n, c='b')

plt.scatter(data['M_star'], abs(data['G_inflow_2.5'])/data['SFR'], c='b', label='In')
plt.scatter(data['M_star'], data['G_outflow_2.5']/data['SFR'], c='r', label='Out')
plt.plot(data['M_star'], n, c='grey', label='Power Law')

plt.loglog()
plt.ylim(5e-2, 5e2)
plt.xlim(1e3, 1e12)

plt.legend()
plt.xlabel(r'Stellar Mass ($M_{\odot}$) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR and $M_{in}$/SFR', size=15)
plt.title('Power Law Fit Comparison 2.5', size=20)
plt.savefig('a3')

# %%
#Plot N value vs Stellar Mass
# EQ

n = 3.6*(data['M_star']/10**10)**(-.35)     #unitlessRogue['G_outflow_1.5']

#   *1.989e30

plt.figure(figsize=(7,7))
#plt.scatter(data['mass'], n, c='b')

plt.scatter(data['M_star'], abs(data['G_inflow_1.5'])/data['SFR'], c='b', label='In')
plt.scatter(data['M_star'], data['G_outflow_1.5']/data['SFR'], c='r', label='Out')
plt.plot(data['M_star'], n, c='grey', label='Power Law')

plt.loglog()
plt.ylim(5e-2, 5e2)
plt.xlim(1e3, 1e12)

plt.legend()
plt.xlabel(r'Stellar Mass ($M_{\odot}$) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR and $M_{in}$/SFR', size=15)
plt.title('Power Law Fit Comparison 1.5', size=20)
# Out:
# Text(0.5, 1.0, 'Power Law Fit Comparison 1.5')

# %%
#Plot N value vs Stellar Mass
# EQ

n = 3.6*(data['M_star']/10**10)**(-.35)     #unitlessRogue['G_outflow_1.5']

#   *1.989e30

plt.figure(figsize=(7,7))
#plt.scatter(data['mass'], n, c='b')

plt.scatter(data['M_star'], abs(data['G_inflow_2.5'])/data['SFR'], c='dodgerblue', label='In 2.5', s=30)
plt.scatter(data['M_star'], data['G_outflow_2.5']/data['SFR'], c='tomato', label='Out 2.5', s=30)
plt.scatter(data['M_star'], abs(data['G_inflow_1.5'])/data['SFR'], c='darkblue', label='In 1.5', s=30)
plt.scatter(data['M_star'], data['G_outflow_1.5']/data['SFR'], c='maroon', label='Out 1.5', s=30)
plt.plot(data['M_star'], n, c='grey', label='Power Law')

plt.loglog()
plt.ylim(5e-2, 5e2)
plt.xlim(1e3, 1e12)

plt.legend()

plt.xlabel(r'Stellar Mass ($M_{\odot}$) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR and $M_{in}$/SFR', size=15)
plt.title('Power Law Fit Comparison', size=20)
plt.savefig('a4')

# %%
#Plot N value vs Stellar Mass
# EQ

n = 3.6*(data['M_star']/10**10)**(-.35)     #unitlessRogue['G_outflow_1.5']

#   *1.989e30

plt.figure(figsize=(7,7))
#plt.scatter(data['mass'], n, c='b')

plt.scatter(data['M_star'], data['G_outflow_2.5']/data['SFR'], c='orange', label='SF')
plt.scatter(data['M_star'][data['sSFR']<1e-11], data['G_outflow_2.5'][data['sSFR']<1e-11]/data['SFR'][data['sSFR']<1e-11], c='indigo', label='Q')
plt.plot(data['M_star'], n, c='grey', label='Power Law')

plt.legend()
plt.loglog()
plt.ylim(5e-2, 5e2)
plt.xlim(1e3, 1e12)

plt.xlabel(r'Stellar Mass ($M_{\odot}$) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Quenched Comparison 2.5', size=20)
plt.savefig('a5')

# %%
#Plot N value vs Stellar Mass
# EQ

n = 3.6*(data['M_star']/10**10)**(-.35)     #unitlessRogue['G_outflow_1.5']

#   *1.989e30

plt.figure(figsize=(7,7))
#plt.scatter(data['mass'], n, c='b')

plt.scatter(data['M_star'], data['G_outflow_1.5']/data['SFR'], c='gold', label='SF')
plt.scatter(data['M_star'][data['sSFR']<1e-11], data['G_outflow_1.5'][data['sSFR']<1e-11]/data['SFR'][data['sSFR']<1e-11], c='m', label='Q')
plt.plot(data['M_star'], n, c='grey', label='Power Law')

plt.legend()
plt.loglog()
plt.ylim(5e-2, 5e2)
plt.xlim(1e3, 1e12)

plt.xlabel(r'Stellar Mass ($M_{\odot}$) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Quenched Comparison 1.5', size=20)
# Out:
# Text(0.5, 1.0, 'Quenched Comparison 1.5')

# %%
#Plot N value vs Stellar Mass
# EQ

n = 3.6*(data['M_star']/10**10)**(-.35)     #unitlessRogue['G_outflow_1.5']

#   *1.989e30

plt.figure(figsize=(7,7))
#plt.scatter(data['mass'], n, c='b')

plt.scatter(data['M_star'], data['G_outflow_2.5']/data['SFR'], c='orange', label='SF 2.5')
plt.scatter(data['M_star'][data['sSFR']<1e-11], data['G_outflow_2.5'][data['sSFR']<1e-11]/data['SFR'][data['sSFR']<1e-11], c='indigo', label='Q 2.5')
plt.scatter(data['M_star'], data['G_outflow_1.5']/data['SFR'], c='gold', label='SF 1.5')
plt.scatter(data['M_star'][data['sSFR']<1e-11], data['G_outflow_1.5'][data['sSFR']<1e-11]/data['SFR'][data['sSFR']<1e-11], c='m', label='Q 1.5')

plt.plot(data['M_star'], n, c='grey', label='Power Law')

plt.legend()
plt.loglog()
plt.ylim(5e-2, 5e2)
plt.xlim(1e3, 1e12)

plt.xlabel(r'Stellar Mass ($M_{\odot}$) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Quenched Comparison', size=20)
# Out:
# Text(0.5, 1.0, 'Quenched Comparison')

# %%
#Vc == ((Gravitational constant * Halo Mass)/Rvir)**(1/2)
G = 4.302*1e-3           #in pc/Msol(km/s)**2
h = 0.6776942783267969          #halo.properties['h']
Rvir = data['Rvir']*1000*h
V_c = (G* data['mass']/Rvir)**(1/2)     #km/s

# %%
# EQ most likely all values will be less than 60km\s

nlow = 2.9*(V_c/60)**(-3.2)
nhigh =  2.9*(V_c/60)**(-1)

plt.figure(figsize=(7,7))

plt.scatter(V_c, data['G_outflow_2.5']/data['SFR'], c='r')
plt.plot(V_c, nlow, c='grey')
plt.plot(V_c, nhigh, c='grey')


plt.loglog()
plt.ylim(5e-2, 5e2)
plt.xlim(2, 4e2)

plt.xlabel(r'$V_{c}$ (Km\s) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Broken Power Law Fit Muratov', size=20)
# Out:
# Text(0.5, 1.0, 'Broken Power Law Fit Muratov')

# %%
plt.figure(figsize=(7,7))

plt.scatter(V_c, data['G_outflow_2.5']/data['SFR'], c='r')

x1 = [19.72, 60]
x2 = [60, 513.99]
y1 = [102.042, 2.9]
y2 = [2.9, .399]

plt.plot(x1,y1, 'b-')
plt.plot(x2,y2, 'b-')

plt.loglog()
plt.ylim(5e-2, 5e2)
plt.xlim(2e1, 5e2)

plt.xlabel(r'$V_{c}$ (Km\s) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Broken Power Law Fit Muratov 2.5', size=20)
plt.show()
plt.savefig('a6')

# %%
plt.figure(figsize=(7,7))

plt.scatter(V_c, data['G_outflow_1.5']/data['SFR'], c='r')

x1 = [19.72, 60]
x2 = [60, 513.99]
y1 = [102.042, 2.9]
y2 = [2.9, .399]

plt.plot(x1,y1, 'b-')
plt.plot(x2,y2, 'b-')

plt.loglog()
plt.ylim(5e-2, 5e2)
plt.xlim(2e1, 5e2)

plt.xlabel(r'$V_{c}$ (Km\s) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Broken Power Law Fit Muratov 1.5', size=20)
plt.show()
plt.savefig('a7')

# %%
plt.figure(figsize=(7,7))

plt.scatter(V_c, data['G_outflow_0']/data['SFR'], c='r')

x1 = [19.72, 60]
x2 = [60, 513.99]
y1 = [102.042, 2.9]
y2 = [2.9, .399]

plt.plot(x1,y1, 'b-')
plt.plot(x2,y2, 'b-')

plt.loglog()
plt.ylim(5e-3, 5e2)
plt.xlim(2e1, 5e2)

plt.xlabel(r'$V_{c}$ (Km\s) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Broken Power Law Fit Muratov 0', size=20)
plt.show()
plt.savefig('a7')

# %%
plt.figure(figsize=(7,7))

plt.scatter(V_c, data['G_outflow_0']/data['SFR'], c='black')
plt.scatter(V_c, data['G_outflow_2.5']/data['SFR'], c='tomato')
plt.scatter(V_c, data['G_outflow_1.5']/data['SFR'], c='maroon')

x1 = [19.72, 60]
x2 = [60, 513.99]
y1 = [102.042, 2.9]
y2 = [2.9, .399]

plt.plot(x1,y1, 'b-')
plt.plot(x2,y2, 'b-')

plt.loglog()
plt.ylim(5e-3, 5e2)
plt.xlim(2e1, 5e2)

plt.xlabel(r'$V_{c}$ (Km\s) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Broken Power Law Fit Muratov', size=20)
plt.show()
plt.savefig('a8')

# %%
#Plot N value vs Vc

# EQ most likely all values will be less than 60km\s

nlow = 2.9*(V_c/60)**(-3.2)
nhigh =  2.9*(V_c/60)**(-1)

plt.figure(figsize=(7,7))

plt.scatter(V_c, abs(data['G_inflow_2.5'])/data['SFR'], c='b', label='In')
plt.scatter(V_c, data['G_outflow_2.5']/data['SFR'], c='r', label='Out')
plt.plot(V_c, nlow, c='grey')
plt.plot(V_c, nhigh, c='grey')

plt.loglog()
plt.ylim(5e-2, 5e2)
plt.xlim(2e1, 4e2)

plt.legend()
plt.xlabel(r'$V_{c}$ (Km\s) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR and $M_{in}$/SFR', size=15)
plt.title('Broken Power Law Comparison', size=20)
plt.savefig('a9')

# %%
nlow = 2.9*(V_c/60)**(-3.2)
nhigh =  2.9*(V_c/60)**(-1)

Rvir2 = data['Rvir'][data['sSFR']<1e-11]*1000*h
Vel = (G* data['mass'][data['sSFR']<1e-11]/Rvir2)**(1/2)     #km/s

plt.figure(figsize=(7,7))

plt.scatter(V_c, data['G_outflow_2.5']/data['SFR'], c='gold')
plt.scatter(Vel, data['G_outflow_2.5'][data['sSFR']<1e-11]/data['SFR'][data['sSFR']<1e-11], c='indigo')
plt.plot(V_c, nlow, c='grey')
plt.plot(V_c, nhigh, c='grey')

plt.loglog()
plt.ylim(5e-2, 5e2)
plt.xlim(2e1, 4e2)

plt.xlabel(r'$V_{c}$ (Km\s) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Broken Power Law Fit Muratov', size=20)
plt.savefig('b')

# %%
#Plot N value vs Vc
M_60 = 32601445288.3066
# EQ most likely all values will be less than 60km\s

nlow = 2.9*(data['mass']/M_60)**(-1.1)
nhigh =  2.9*(data['mass']/M_60)**(-.33)

plt.figure(figsize=(7,7))

plt.scatter(data['mass'], data['G_outflow_2.5']/data['SFR'], c='r')
plt.plot(data['mass'], nlow, c='grey')
plt.plot(data['mass'], nhigh, c='grey')

plt.loglog()
plt.ylim(1e-2, 1e3)
plt.xlim(1e8, 1e13)

plt.xlabel(r'Halo Mass ($M_{\odot}$) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR', size=15)
plt.title('Broken Power Law Fit Muratov', size=20)
plt.savefig('b1')

# %%
#Plot N value vs Vc
M_60 = 32601445288.3066
# EQ most likely all values will be less than 60km\s

nlow = 2.9*(data['mass']/M_60)**(-1.1)
nhigh =  2.9*(data['mass']/M_60)**(-.33)

plt.figure(figsize=(7,7))

plt.scatter(data['mass'], data['G_outflow_2.5']/data['SFR'], c='r')
plt.scatter(data['mass'], abs(data['G_inflow_2.5']/data['SFR']), c='b')
plt.plot(data['mass'], nlow, c='grey')
plt.plot(data['mass'], nhigh, c='grey')
#Plot N value vs Vc

plt.figure(figsize=(7,7))

plt.scatter(V_c, data['G_outflow_2.5'], c='gold', label='SF')
plt.scatter(Vel, data['G_outflow_2.5'][data['sSFR']<1e-11], c='indigo', label='Q')

plt.loglog()
plt.xlim(10, 1e3)
plt.ylim(1e-6, 50)

plt.legend()
plt.xlabel(r'$V_{c}$ (Km\s)', size=15)
plt.ylabel(r'n = $M_{out}$', size=15)
plt.title('Power law fit Muratov', size=20)
plt.savefig('b5')
plt.loglog()
plt.ylim(1e-2, 1e3)
plt.xlim(1e8, 1e13)

plt.xlabel(r'Halo Mass ($M_{\odot}$) at z=0', size=15)
plt.ylabel(r'n = $M_{out}$/SFR and $M_{in}$/SFR', size=15)
plt.title('Broken Power Law Fit Muratov', size=20)
plt.savefig('b2')

# %%
#Plot N value vs Vc

plt.figure(figsize=(7,7))

plt.scatter(V_c, abs(data['G_inflow_2.5']), c='b', label='In')
plt.scatter(V_c, data['G_outflow_2.5'], c='r', label='Out')

plt.loglog()
plt.xlim(10, 1e3)
plt.ylim(1e-6, 50)

plt.legend()
plt.xlabel(r'$V_{c}$ (Km\s)', size=15)
plt.ylabel(r'n = $M_{out}$ and $M_{in}$', size=15)
plt.title('Power law fit Muratov 2.5', size=20)
plt.savefig('b3')

# %%
#Plot N value vs Vc

plt.figure(figsize=(7,7))

plt.scatter(V_c, abs(data['G_inflow_1.5']), c='b', label='In')
plt.scatter(V_c, data['G_outflow_1.5'], c='r', label='Out')

plt.loglog()
plt.xlim(10, 1e3)
plt.ylim(1e-6, 50)

plt.legend()
plt.xlabel(r'$V_{c}$ (Km\s)', size=15)
plt.ylabel(r'n = $M_{out}$ and $M_{in}$', size=15)
plt.title('Power law fit Muratov 1.5', size=20)
# Out:
# Text(0.5, 1.0, 'Power law fit Muratov 1.5')

# %%
#Plot N value vs Vc

plt.figure(figsize=(7,7))

plt.scatter(V_c, abs(data['G_inflow_0']), c='b', label='In')
plt.scatter(V_c, data['G_outflow_0'], c='r', label='Out')

plt.loglog()
plt.xlim(10, 1e3)
plt.ylim(1e-7, 50)

plt.legend()
plt.xlabel(r'$V_{c}$ (Km\s)', size=15)
plt.ylabel(r'n = $M_{out}$ and $M_{in}$', size=15)
plt.title('Power law fit Muratov 0', size=20)
# Out:
# Text(0.5, 1.0, 'Power law fit Muratov 0')

# %%
#Plot N value vs Vc

plt.figure(figsize=(7,7))
#Plot N value vs Vc

plt.figure(figsize=(7,7))

plt.scatter(V_c, data['G_outflow_2.5'], c='gold', label='SF')
plt.scatter(Vel, data['G_outflow_2.5'][data['sSFR']<1e-11], c='indigo', label='Q')

plt.loglog()
plt.xlim(10, 1e3)
plt.ylim(1e-6, 50)

plt.legend()
plt.xlabel(r'$V_{c}$ (Km\s)', size=15)
plt.ylabel(r'n = $M_{out}$', size=15)
plt.title('Power law fit Muratov', size=20)
plt.savefig('b5')
plt.scatter(V_c, abs(data['G_inflow_2.5']), c='dodgerblue', label='In 2.5', s=20)
plt.scatter(V_c, data['G_outflow_2.5'], c='tomato', label='Out 2.5', s=20)
plt.scatter(V_c, abs(data['G_inflow_1.5']), c='darkblue', label='In 1.5', s=20)
plt.scatter(V_c, data['G_outflow_1.5'], c='maroon', label='Out 1.5', s=20)

plt.loglog()
plt.xlim(10, 1e3)
plt.ylim(1e-6, 50)

plt.legend()
plt.xlabel(r'$V_{c}$ (Km\s)', size=15)
plt.ylabel(r'n = $M_{out}$ and $M_{in}$', size=15)
plt.title('Power law fit Muratov', size=20)
plt.savefig('b4')

# %%
#Plot N value vs Vc

plt.figure(figsize=(7,7))

plt.scatter(V_c, data['G_outflow_2.5'], c='gold', label='SF')
plt.scatter(Vel, data['G_outflow_2.5'][data['sSFR']<1e-11], c='indigo', label='Q')

plt.loglog()
plt.xlim(10, 1e3)
plt.ylim(1e-6, 50)

plt.legend()
plt.xlabel(r'$V_{c}$ (Km\s)', size=15)
plt.ylabel(r'n = $M_{out}$', size=15)
plt.title('Power law fit Muratov', size=20)
plt.savefig('b5')

# %%
#Plot N value vs Vc

plt.figure(figsize=(7,7))

plt.scatter(V_c, abs(data['G_outflow_2.5']+data['G_inflow_2.5']), c='b', label='In')
plt.scatter(V_c, data['G_outflow_2.5']+data['G_inflow_2.5'], c='r', label='Out')

plt.loglog()
plt.xlim(10, 1e3)
plt.ylim(1e-6, 50)

plt.legend()
plt.xlabel(r'$V_{c}$ (Km/s)', size=15)
plt.ylabel(r'($M_{\odot}$/yr)', size=15)
plt.title('Net Mass Flux', size=20)
plt.savefig('b6')

# %%
#Plot N value vs Vc

plt.figure(figsize=(7,7))

plt.scatter(V_c, abs(data['G_inflow_2.5']), c='darkblue', label='In')
plt.scatter(V_c, data['G_outflow_2.5'], c='crimson', label='Out')

plt.scatter(V_c, abs(data['G_outflow_2.5']+data['G_inflow_2.5']), c='cornflowerblue', label='Net In')
plt.scatter(V_c, data['G_outflow_2.5']+data['G_inflow_2.5'], c='lightcoral', label='Net Out')

plt.loglog()
plt.xlim(10, 1e3)
plt.ylim(1e-6, 50)

plt.legend()
plt.xlabel(r'$V_{c}$ (Km\s)', size=15)
plt.ylabel(r'($M_{\odot}$/yr)', size=15)
plt.title('Power law fit Muratov', size=20)
plt.savefig('b7')

# %%
plt.figure(figsize=(7,7))

plt.scatter(data['M_star'], data['G_outflow_2.5'], c='r', label='Out')
plt.scatter(data['M_star'], abs(data['G_inflow_2.5']), c='b', label='In')

plt.loglog()
plt.ylim(1e-7, 100)
plt.xlim(1e1, 1e13)

plt.legend()
plt.xlabel(r'Stellar Mass ($M_{\odot}$)', size=15)
plt.ylabel(r'n = $M_{out}$ and $M_{in}$', size=15)
plt.title('Outflow and Inflow rates 2.5', size=20)
plt.savefig('b8')

# %%
plt.figure(figsize=(7,7))

plt.scatter(data['M_star'], data['G_outflow_1.5'], c='r', label='Out')
plt.scatter(data['M_star'], abs(data['G_inflow_1.5']), c='b', label='In')

plt.loglog()
plt.ylim(1e-7, 100)
plt.xlim(1e1, 1e13)

plt.legend()
plt.xlabel(r'Stellar Mass ($M_{\odot}$)', size=15)
plt.ylabel(r'n = $M_{out}$ and $M_{in}$', size=15)
plt.title('Outflow and Inflow rates 1.5', size=20)
# Out:
# Text(0.5, 1.0, 'Outflow and Inflow rates 1.5')

# %%
plt.figure(figsize=(7,7))

plt.scatter(data['M_star'], data['G_outflow_0'], c='r', label='Out')
plt.scatter(data['M_star'], abs(data['G_inflow_0']), c='b', label='In')

plt.loglog()
plt.ylim(1e-7, 100)
plt.xlim(1e1, 1e13)

plt.legend()
plt.xlabel(r'Stellar Mass ($M_{\odot}$)', size=15)
plt.ylabel(r'n = $M_{out}$ and $M_{in}$', size=15)
plt.title('Outflow and Inflow rates 0', size=20)
# Out:
# Text(0.5, 1.0, 'Outflow and Inflow rates 0')

# %%
plt.figure(figsize=(7,7))

plt.scatter(data['M_star'], data['G_outflow_1.5'], c='maroon', label='Out 1.5', s=20)
plt.scatter(data['M_star'], abs(data['G_inflow_1.5']), c='darkblue', label='In 1.5', s=20)
plt.scatter(data['M_star'], data['G_outflow_2.5'], c='tomato', label='Out 2.5', s=20)
plt.scatter(data['M_star'], abs(data['G_inflow_2.5']), c='dodgerblue', label='In 2.5', s=20)

plt.loglog()
plt.ylim(1e-7, 100)
plt.xlim(1e1, 1e13)

plt.legend()
plt.xlabel(r'Stellar Mass ($M_{\odot}$)', size=15)
plt.ylabel(r'n = $M_{out}$ and $M_{in}$', size=15)
plt.title('Outflow and Inflow rates', size=20)
plt.savefig('b9')

# %%
plt.figure(figsize=(7,7))

plt.scatter(data['M_star'], data['G_outflow_2.5'], c='gold', label='SF')
plt.scatter(data['M_star'][data['sSFR']<1e-11], data['G_outflow_2.5'][data['sSFR']<1e-11], c='indigo', label='Q')
plt.scatter(data1['M_star'][data1['haloid']==28], data1['G_outflow_2.5'][data1['haloid']==28])
plt.scatter(data1['M_star'][data1['haloid']==36], data1['G_outflow_2.5'][data1['haloid']==36])
plt.scatter(data1['M_star'][data1['haloid']==64], data1['G_outflow_2.5'][data1['haloid']==64])
plt.scatter(data2['M_star'][data2['haloid']==17], data2['G_outflow_2.5'][data2['haloid']==17])
plt.scatter(data3['M_star'][data3['haloid']==48], data3['G_outflow_2.5'][data3['haloid']==48], c='black')

plt.loglog()
plt.ylim(1e-7, 100)
plt.xlim(1e1, 1e13)

plt.legend()
plt.xlabel(r'Stellar Mass ($M_{\odot}$)', size=15)
plt.ylabel(r'n = $M_{out}$', size=15)
plt.title('Quenching relationships', size=20)
plt.savefig('c')

# %%
plt.figure(figsize=(7,7))

plt.scatter(data4['h1dist'], data4['G_outflow_2.5'], c='r', label='Out')
plt.scatter(data4['h1dist'], abs(data4['G_inflow_2.5']),c='b', label='In')
plt.legend()
plt.scatter(data3['h1dist'], data3['G_outflow_2.5'], c='r')
plt.scatter(data3['h1dist'], abs(data3['G_inflow_2.5']),c='b')
plt.scatter(data2['h1dist'], data2['G_outflow_2.5'], c='r')
plt.scatter(data2['h1dist'], abs(data2['G_inflow_2.5']),c='b')
plt.scatter(data1['h1dist'], data1['G_outflow_2.5'], c='r')
plt.scatter(data1['h1dist'], abs(data1['G_inflow_2.5']),c='b')

#plt.loglog()
plt.semilogx()
plt.ylim(-1, 2)
plt.xlim(10, 5e3)

plt.xlabel('Distance to Host (kpc)', size=15)
plt.ylabel(r'n = $M_{out}$ and $M_{in}$', size=15)
plt.title('Distance to Host and Gas Flow', size=20)
plt.savefig('c1')

# %%
plt.figure(figsize=(7,7))

plt.scatter(data4['h1dist'], data4['G_outflow_2.5'], c='r', label='Out')
plt.scatter(data4['h1dist'], abs(data4['G_inflow_2.5']),c='b', label='In')
plt.legend()
plt.scatter(data3['h1dist'], data3['G_outflow_2.5'], c='r')
plt.scatter(data3['h1dist'], abs(data3['G_inflow_2.5']),c='b')
plt.scatter(data2['h1dist'], data2['G_outflow_2.5'], c='r')
plt.scatter(data2['h1dist'], abs(data2['G_inflow_2.5']),c='b')
plt.scatter(data1['h1dist'], data1['G_outflow_2.5'], c='r')
plt.scatter(data1['h1dist'], abs(data1['G_inflow_2.5']),c='b')

plt.loglog()
plt.ylim(1e-5, 5)
plt.xlim(10, 5e3)

plt.xlabel('Distance to Host (kpc)', size=15)
plt.ylabel(r'n = $M_{out}$ and $M_{in}$', size=15)
plt.title('Distance to Host and Gas Flow', size=20)
plt.savefig('c2')

# %%
plt.figure(figsize=(7,7))

plt.scatter(data4['h1dist'][data4['sSFR']<1e-11], data4['G_inflow_2.5'][data4['sSFR']<1e-11],c='indigo', label='Q')
plt.scatter(data4['h1dist'], data4['G_outflow_2.5'], c='gold', label='SF')
plt.legend()
plt.scatter(data1['h1dist'][data1['sSFR']<1e-11], data1['G_inflow_2.5'][data1['sSFR']<1e-11],c='indigo', label='Q')
plt.scatter(data1['h1dist'], data1['G_outflow_2.5'], c='gold', label='SF')
plt.scatter(data2['h1dist'][data2['sSFR']<1e-11], data2['G_inflow_2.5'][data2['sSFR']<1e-11],c='indigo', label='Q')
plt.scatter(data2['h1dist'], data2['G_outflow_2.5'], c='gold', label='SF')
plt.scatter(data3['h1dist'][data3['sSFR']<1e-11], data3['G_inflow_2.5'][data3['sSFR']<1e-11],c='indigo', label='Q')
plt.scatter(data3['h1dist'], data3['G_outflow_2.5'], c='gold', label='SF')

plt.semilogx()
plt.ylim(-1e-1, 1.25)
plt.xlim(10, 5e3)

plt.xlabel('Distance to Host (kpc)', size=15)
plt.ylabel(r'n = $M_{out}$ and $M_{in}$', size=15)
plt.title('Host Distance and Quenching', size=20)
plt.savefig('c3')

# %%
plt.figure(figsize=(7,7))

plt.scatter(data['G_outflow_2.5'], data['SFR'], c='r')

plt.loglog()
plt.xlim(1e-4, 10)
plt.ylim(1e-6, 1e2)

plt.xlabel('SFR ($M_{\odot}$/yr)')
plt.ylabel('Outflow ($M_{\odot}$/yr)')
plt.title('Outflow vs SFR Muratov 2.5')

plt.savefig('c4')

# %%
plt.figure(figsize=(7,7))

plt.scatter(data['G_outflow_1.5'], data['SFR'], c='r')

plt.loglog()
plt.xlim(1e-4, 100)
plt.ylim(1e-6, 1e2)

plt.xlabel('SFR ($M_{\odot}$/yr)')
plt.ylabel('Outflow ($M_{\odot}$/yr)')
plt.title('Outflow vs SFR Muratov 1.5')

plt.savefig('c5')

# %%
plt.figure(figsize=(7,7))

plt.scatter(data['G_outflow_2.5'], data['SFR'], c='tomato', label='2.5')
plt.scatter(data['G_outflow_1.5'], data['SFR'], c='maroon', label='1.5')

plt.loglog()
plt.xlim(1e-4, 100)
plt.ylim(1e-6, 1e2)

plt.legend()
plt.xlabel('SFR ($M_{\odot}$/yr)')
plt.ylabel('Outflow ($M_{\odot}$/yr)')
plt.title('Outflow vs SFR Muratov')

plt.savefig('c6')

# %%
plt.figure(figsize=(7,7))

plt.scatter(data['G_outflow_2.5'], data['SFR'], c='tomato', label='Out 2.5')
plt.scatter(data['G_outflow_1.5'], data['SFR'], c='maroon', label='Out 1.5')
plt.scatter(abs(data['G_inflow_2.5']), data['SFR'], c='dodgerblue', label='In 2.5')
plt.scatter(abs(data['G_inflow_1.5']), data['SFR'], c='darkblue', label='In 1.5')


plt.loglog()
plt.xlim(1e-4, 100)
plt.ylim(1e-6, 1e2)

plt.legend()
plt.xlabel('SFR ($M_{\odot}$/yr)')
plt.ylabel('($M_{\odot}$/yr)')
plt.title('Flow vs SFR Muratov')

plt.savefig('c7')
